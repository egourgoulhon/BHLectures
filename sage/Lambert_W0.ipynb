# %% [markdown]
# # Lambert function $W_0$

# %%
# %display latex

# %%
f(x) = x*exp(x)
f
# Out:
# x |--> x*e^x

# %%
graph = plot(f(x), (x,-1, 1), axes_labels=[r'$x$', r'$f(x)$'], thickness=2, gridlines=True)
graph
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
graph.save('max_xex.pdf')

# %%
f(-1)
# Out:
# -e^(-1)

# %%
graph = plot(lambert_w(x), (x,-1/e, 2.7), axes_labels=[r'$y$', r'$W_0(y)$'], 
              thickness=2, gridlines=True)
graph
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
graph.save('max_lambert_W0.pdf')

# %%
def w(x):
    return RDF(lambert_w(RDF(x/e)) + 1)

# %%
w(0)
# Out:
# 1.0

# %%
w(-1)
# Out:
# -4.47151982108096e-09

# %%
w(2)
# Out:
# 1.463055513365549

# %%
graph = plot(w, (x, -1, 5), aspect_ratio=1, axes_labels=[r'$x$', r'$\tilde{W}_0(x)$'], 
             thickness=2, gridlines=True)
graph
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
graph.save('max_lambert_rescaled.pdf')
