# %%
g = plot(x + 2*ln(abs(x/2-1)), (x, 0, 8), thickness=2, ticks=[None, 1],
         gridlines='minors', axes_labels=[r'$r/m$', r'$r_*/m$'],
         aspect_ratio=1, ymin=-8)
g
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g.save("sch_tortoise.pdf")

# %%
g = plot(exp(x/2)*(x/2-1), (x, 0, 4), thickness=2, ticks=[None, 1],
         gridlines='minors', axes_labels=[r'$r/m$', r'$X^2-T^2$'])
g
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g.save("sch_X2mT2.pdf")
