# %%
version()
# Out:
# 'SageMath version 10.4.beta6, Release Date: 2024-05-12'

# %%
# %display latex

# %%
mirr = sqrt(1/2*(1 + sqrt(1 - x^2)))
mirr
# Out:
# sqrt(1/2*sqrt(-x^2 + 1) + 1/2)

# %%
graph = plot(mirr, (x, 0, 1), thickness=2, 
             fill='max', fillcolor='lightblue',
             axes_labels=(r'$J/M^2$', r'$M_{\rm irr}/M$'))
show(graph, frame=True, gridlines=True, axes=False)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
graph.save('evo_irred_mass.pdf', frame=True, gridlines=True, axes=False)
